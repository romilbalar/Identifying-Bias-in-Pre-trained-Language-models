# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import csv
import sklearn

data = pd.read_csv("/content/drive/MyDrive/NLP_Project/glove.6B.50d.txt", sep=" ", index_col=0, header=None, 
                       quoting=csv.QUOTE_NONE)
# vocabs = list(glove_df.index)

# %%
from sklearn import cluster

k_means = cluster.KMeans(n_clusters=2, max_iter=100, random_state=1)
k_means.fit(data) 
labels = k_means.labels_
# Out:
#            1         2        3   ...        48        49       50
# 0                                 ...
# the  0.418000  0.249680 -0.41242  ... -0.184110 -0.115140 -0.78581
# ,    0.013441  0.236820 -0.16899  ... -0.566570  0.044691  0.30392
# .    0.151640  0.301770 -0.16763  ... -0.356520  0.016413  0.10216
# of   0.708530  0.570880 -0.47160  ... -0.225620 -0.093918 -0.80375
# to   0.680470 -0.039263  0.30186  ... -0.073297 -0.064699 -0.26044
#
# [5 rows x 50 columns]

# %%
centroids = k_means.cluster_centers_
pd.DataFrame(centroids,columns=data.columns)
# Out:
#          1         2         3   ...        48        49        50
# 0 -0.068720 -0.275021 -0.053477  ...  0.171855  0.006733 -0.162808
# 1 -0.219554 -0.309043  0.049347  ... -0.005620  0.006223  0.285255
#
# [2 rows x 50 columns]

# %%
man = data.loc['man']
woman = data.loc['woman']

# %%
from sklearn import metrics
from scipy import spatial
import numpy as np
# result =spatial.distance.cosine(woman, centroids[1])
result = np.linalg.norm(data-centroids[0],axis=1)


# data.at[361899]

#sklearn.metrics.pairwise.cosine_similarity(man, centroids[0], dense_output=True)

# %%
data.iloc[361899]

# %%
from sklearn import cluster
import matplotlib.pyplot as plt
labels1 = pd.DataFrame(k_means.labels_,columns=['Cluster ID'])
print(data.shape,labels1.shape)
result1 = pd.concat((data,labels1), axis=0)
labels2 = pd.DataFrame(k_means.labels_,columns=['Cluster ID'])
result2 = pd.concat((data,labels2), axis=0)

fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12,5))
result1.plot.scatter(x='x',y='y',c='Cluster ID',colormap='jet',ax=ax1)
ax1.set_title('K-means Clustering')
result2.plot.scatter(x='x',y='y',c='Cluster ID',colormap='jet',ax=ax2)
ax2.set_title('K-means Clustering')

# %%
import torch
device= torch.device("cuda:0")

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA(n_components=0.9, random_state=10).fit(X_scaled)
X_pca = pca.transform(X_scaled)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, s=20, cmap='Set1');
plt.colorbar()
X_pca.shape

# %%
from sklearn.manifold import TSNE
import numpy as np
X = data

tsne = TSNE(verbose=1, perplexity=5)
X_embedded = torch.from_numpy(tsne.fit_transform(np.array(X))).to(device)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 400001 samples in 0.018s...
# [t-SNE] Computed neighbors for 400001 samples in 3614.061s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 400001
# [t-SNE] Computed conditional probabilities for sample 2000 / 400001
# [t-SNE] Computed conditional probabilities for sample 3000 / 400001
# [t-SNE] Computed conditional probabilities for sample 4000 / 400001
# [t-SNE] Computed conditional probabilities for sample 5000 / 400001
# [t-SNE] Computed conditional probabilities for sample 6000 / 400001
# ...
